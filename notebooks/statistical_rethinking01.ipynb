# %% [markdown]
# <a href="https://colab.research.google.com/github/Sparrow0hawk/statistical-rethinking/blob/main/notebooks/statistical_rethinking01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statistical rethinking

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ways = np.array([3,8,9])

# %%
ways.sum()
# Out:
# 20

# %%
ways / ways.sum()
# Out:
# array([0.15, 0.4 , 0.45])

# %%
# globe tossing results, 1- water, 0- land
result = [1,0,1,1,1,0,1,0,1]

# %%
from math import factorial

def binomial(counts, total, prob):
  ####### calculate total possible number of occurences ####################### calculate the probability of each outcome
  return (factorial(total) / (factorial(counts) * factorial(total - counts))) * (prob ** counts) * ((1-prob)**(total - counts))

# %%
binomial(6, 9, 0.5)
# Out:
# 0.1640625

# %%
from scipy.stats import binom

# %%
binom.pmf(6,9,0.5)
# Out:
# 0.16406250000000006

# %%
grid = np.linspace(0,1,num=1000)

prior = np.repeat(1,1000)

prob_data = binom.pmf(6, 9, grid)

posterior = prob_data * prior

posterior = posterior / sum(posterior)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20,6))
fig.suptitle('Horizontally stacked subplots')
ax1.plot(grid)
ax1.set_title("Grid values")
ax2.plot(prior)
ax2.set_title("Prior")
ax3.plot(prob_data)
ax3.set_title("Likelihood")
ax4.plot(posterior)
ax4.set_title("Posterior")
# Out:
# Text(0.5, 1.0, 'Posterior')

# %%
# randomly sample from our grid approx posterior

samples = np.random.choice(grid,size=(1000,), replace=True, p=posterior)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))
ax1.scatter(y=samples, x=range(0,len(samples)), alpha=0.4)
ax1.set_title("Sampling from posterior")
ax2.hist(samples)
ax2.set_title("Histogram of samples")
# Out:
# Text(0.5, 1.0, 'Histogram of samples')
